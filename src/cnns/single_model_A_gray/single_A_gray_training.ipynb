# %% [markdown]
# ## Model Training Explanation
# This notebook is about training 1 Model A with Grayscale Images.

# %%
import matplotlib.pyplot as plt

# %%
from importlib import reload

import vpc_cnn_a
import vpc_data

reload(vpc_cnn_a)
reload(vpc_data)
# Out:
# <module 'vpc_data' from 'c:\\Universidade\\vpc\\VPC-TP\\src\\single_model_A_gray\\vpc_data.py'>

# %%
X_train, y_train, X_val, y_val = vpc_data.load_training_data(validation_split=0.2)
# Out:
# Loading Training data from 43 directories
# Training images loaded. Shuffling data.
# X_train_gray.shape (31367, 30, 30, 1)
# X_valid_gray.shape (7842, 30, 30, 1)
# y_train.shape (31367,)
# y_valid.shape (7842,)

# %%
model_a_gray = vpc_cnn_a.CNN_A_Gray("ModelAGray", img_size=30, channels=1)
# Out:
# Model: "ModelAGray"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 30, 30, 1)]       0
# _________________________________________________________________
# resizing (Resizing)          (None, 30, 30, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 32)        112
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 26, 26, 32)        104
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 64)        18496
# ...

# %%
model_a_gray.train( X_train, y_train, X_val, y_val, epochs=120, stop_early=True)
# Out:
# Epoch 1/120
# 981/981 [==============================] - 35s 31ms/step - loss: 0.3695 - accuracy: 0.9009 - val_loss: 0.1153 - val_accuracy: 0.9695
#
# Epoch 00001: val_loss improved from inf to 0.11533, saving model to saved_models\ModelAGray
# INFO:tensorflow:Assets written to: saved_models\ModelAGray\assets
# Epoch 2/120
# 981/981 [==============================] - 37s 37ms/step - loss: 0.0702 - accuracy: 0.9791 - val_loss: 0.1158 - val_accuracy: 0.9667
#
# Epoch 00002: val_loss did not improve from 0.11533
# Epoch 3/120
# 981/981 [==============================] - 29s 29ms/step - loss: 0.0492 - accuracy: 0.9856 - val_loss: 0.0960 - val_accuracy: 0.9736
#
# Epoch 00003: val_loss improved from 0.11533 to 0.09599, saving model to saved_models\ModelAGray
# INFO:tensorflow:Assets written to: saved_models\ModelAGray\assets
# Epoch 4/120
# 981/981 [==============================] - 28s 28ms/step - loss: 0.0434 - accuracy: 0.9865 - val_loss: 0.0472 - val_accuracy: 0.9875
#
# ...

# %%
model_a_gray.plot_history()

# %%
X_test, y_test = vpc_data.load_testing_data()
# Out:
# Loading testing data from 43 directories
# Test images loaded.
# test_gray data shape:  (12630, 30, 30, 1)
# test_labels shape:  (12630,)

# %%
model_a_gray.evaluate(X_test, y_test)
# Out:
# Test Data accuracy:  98.32937450514648
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        60
#            1       0.99      0.99      0.99       720
#            2       0.99      1.00      1.00       750
#            3       1.00      0.96      0.98       450
#            4       1.00      0.99      0.99       660
#            5       0.96      0.99      0.97       630
#            6       1.00      0.85      0.92       150
#            7       0.98      0.98      0.98       450
#            8       0.98      0.97      0.98       450
#            9       0.99      1.00      1.00       480
#           10       1.00      1.00      1.00       660
#           11       0.99      0.98      0.99       420
#           12       0.99      0.99      0.99       690
#           13       1.00      1.00      1.00       720
#           14       0.99      1.00      0.99       270
#           15       0.95      1.00      0.97       210
# ...

# %%
loaded_model_A_gray =  vpc_cnn_a.CNN_A_Gray("ModelAGray", img_size=30, channels=1)
loaded_model_A_gray.load()
loaded_model_A_gray.evaluate_error(X_test, y_test)
# Out:
# Model: "ModelAGray"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 30, 30, 1)]       0
# _________________________________________________________________
# resizing_1 (Resizing)        (None, 30, 30, 1)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 28, 28, 32)        112
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 26, 26, 32)        9248
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 26, 26, 32)        104
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 24, 24, 64)        18496
# ...
