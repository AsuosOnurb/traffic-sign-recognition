# %% [markdown]
# ## Ensemble Version Explanation
# This ensemble is composed of 2 CNN models:
# 1. The first model uses RGB images (no transformations)
# 2. The second model uses grayscale local histogram normalized images
#
# The 2 models use the same architecture: **CNN_C** (found in the file `vpc_cnn_c.py`). They only differ in the input data and input channels.

# %%
from importlib import reload

import vpc_ensemble_model_5c_rgb
import vpc_data

reload(vpc_ensemble_model_5c_rgb)
reload(vpc_data)
# Out:
# <module 'vpc_data' from 'c:\\Universidade\\vpc\\VPC-TP\\src\\ensemble_5c_rgb\\vpc_data.py'>

# %%
ensemble = vpc_ensemble_model_5c_rgb.EnsembleModel5CRGB("5CRGB", img_size=30)
# Out:
# Model: "MemberModelC0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 30, 30, 3)]       0
# _________________________________________________________________
# resizing (Resizing)          (None, 30, 30, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 128)       36992
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 128)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 13, 13, 128)       512
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 128)       147584
# ...

# %%
ensemble.train_ensemble(epochs=120, stop_early=True)
# Out:
# Loading Training data from 43 directories
# Training images loaded. Shuffling data.
# X_train_rgb.shape (31367, 30, 30, 3)
# X_valid_rgb.shape (7842, 30, 30, 3)
# y_train.shape (31367,)
# y_valid.shape (7842,)
# c:\Users\badns\anaconda3\envs\deeplearning_v2\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/120
# 980/980 [==============================] - 131s 124ms/step - loss: 2.5596 - accuracy: 0.3195 - val_loss: 1.1621 - val_accuracy: 0.6414
#
# Epoch 00001: val_loss improved from inf to 1.16214, saving model to saved_models\5CRGB
# INFO:tensorflow:Assets written to: saved_models\5CRGB\assets
# Epoch 2/120
# 980/980 [==============================] - 90s 92ms/step - loss: 0.9201 - accuracy: 0.7311 - val_loss: 0.3534 - val_accuracy: 0.9005
#
# ...

# %%
ensemble.plot_history()

# %%
X_test_rgb, y_test = vpc_data.load_testing_data()
# Out:
# Loading testing data from 43 directories
# Test images loaded.
# test_rgb data shape:  (12630, 30, 30, 3)
# test_labels shape:  (12630,)

# %%
ensemble.evaluate_ensemble(X_test_rgb, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Universidade\vpc\VPC-TP\src\ensemble_5c_rgb\ensemble_training.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Universidade/vpc/VPC-TP/src/ensemble_5c_rgb/ensemble_training.ipynb#ch0000006?line=0'>1</a> ensemble.evaluate_ensemble(X_test_rgb, y_test)
#
# NameError: name 'ensemble' is not defined

# %%
loaded_ensemble_5c_rgb = vpc_ensemble_model_5c_rgb.EnsembleModel5CRGB("5CRGB", img_size=30)
loaded_ensemble_5c_rgb.load_full_model()
loaded_ensemble_5c_rgb.evaluate_ensemble(X_test_rgb, y_test)
loaded_ensemble_5c_rgb.evaluate_error(X_test_rgb, y_test)
# Out:
# Model: "MemberModelC0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_6 (InputLayer)         [(None, 30, 30, 3)]       0
# _________________________________________________________________
# resizing_5 (Resizing)        (None, 30, 30, 3)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 28, 28, 32)        896
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 26, 26, 128)       36992
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 13, 13, 128)       0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 13, 13, 128)       512
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 11, 11, 128)       147584
# ...
